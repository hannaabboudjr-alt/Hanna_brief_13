# %%
import pandas as pd
import numpy as np

df_ar_sa = pd.read_csv("arrets-de-travail-par-secteur-d-activite-naf-1-et-naf-5.csv", sep=";")
print("Loaded successfully! Shape:", df_ar_sa.shape)
# Out:
# Loaded successfully! Shape: (30240, 10)

# %%
df_ar_sa
# Out:
#        annee code_NAF1                        libelle_NAF1  \
# 0       2015         A  Agriculture, sylviculture et pêche
# 1       2015         A  Agriculture, sylviculture et pêche
# 2       2015         A  Agriculture, sylviculture et pêche
# 3       2015         A  Agriculture, sylviculture et pêche
# 4       2015         A  Agriculture, sylviculture et pêche
# ...      ...       ...                                 ...
# 30235   2024         x                    Valeur manquante
# 30236   2024         x                    Valeur manquante
# 30237   2024         x                    Valeur manquante
# 30238   2024         x                    Valeur manquante
# 30239   2024         x                    Valeur manquante
#
#                                          NAF1 code_NAF5  \
# 0      A - Agriculture, sylviculture et pêche     0111Z
# 1      A - Agriculture, sylviculture et pêche     0111Z
# 2      A - Agriculture, sylviculture et pêche     0111Z
# ...

# %%
df_ar_sa.describe()
# Out:
#               annee  nb_jours_arret_travail
# count  30240.000000            2.956500e+04
# mean    2019.500000            1.332736e+05
# std        2.872329            1.608434e+06
# min     2015.000000            0.000000e+00
# 25%     2017.000000            1.377000e+03
# 50%     2019.500000            6.873000e+03
# 75%     2022.000000            3.021000e+04
# max     2024.000000            7.888625e+07
